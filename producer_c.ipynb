# %% [markdown]
# # Kafka Producer for Camera C

# %% [markdown]
# ## Features Implemented
#
# - **Batching logic** based on `batch_id`, with a delay between each batch
# - Inclusion of essential **metadata**, including:
#   - `producer_id` (unique per topic)
#   - `producer_timestamp` (UTC ISO format)
# - Messages are **JSON-encoded** and published to distinct Kafka topics

# %%
# include all necessary imports
from time import sleep
import json
from kafka3 import KafkaProducer
import datetime as dt
import pandas as pd


hostip = "192.168.0.116"


def publish_message(producer_instance, topic_name, file_name):
    """
    Publishes messages from a CSV file to a specified Kafka topic in batch groups.

    Each row in the CSV is converted to a JSON message and published to Kafka. 
    Messages are grouped and sent based on the 'batch_id' column in the CSV. 
    A 5-second delay is introduced between sending each batch.

    Metadata fields 'producer_id' and 'producer_timestamp' are automatically added to each message.

    Parameters:
        producer_instance (KafkaProducer): The Kafka producer instance used to send messages.
        topic_name (str): The name of the Kafka topic to publish to.
        file_name (str): The path to the CSV file containing the event data.

    Raises:
        Exception: Prints the exception message if there is an error during message publishing.
    """
    try:
        df = pd.read_csv(file_name)
        
        # batch based on batch_id
        grouped_df = df.groupby("batch_id")
        for batch_id, group in grouped_df:
            for _,row in group.iterrows():
                key_bytes = topic_name.encode('utf-8') 
                row_to_dict = row.to_dict()
                
                # include metadata
                row_to_dict["producer_id"] = topic_name
                row_to_dict["producer_timestamp"] = dt.datetime.utcnow().isoformat()
                
                value_bytes = json.dumps(row_to_dict).encode()
                producer_instance.send(topic_name, key=key_bytes, value=value_bytes)
                print(f'Message {batch_id + 1} published successfully: {row}')
            sleep(5) # add delay between each batch
                
            
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))
        
def connect_kafka_producer():
    """
    Establishes a connection to a Kafka broker and returns a KafkaProducer instance.
    The producer connects to a broker running at the specified host IP and port 9092.
    
    Returns:
        KafkaProducer or None: The Kafka producer instance if connection is successful, otherwise None.

    Raises:
        Exception: Prints the exception message if connection fails.
    """
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=[f'{hostip}:9092'],
                                  api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
    finally:
        return _producer

# %%
topic3 = 'Camera_C'
producer_3 = connect_kafka_producer()
publish_message(producer_3,topic3,"camera_event_C.csv" )
# Out:
# Message 2 published successfully: event_id         d86e8cdb-c387-4ccb-b35a-346302238824
# batch_id                                            1
# car_plate                                     UTT 229
# camera_id                                           3
# timestamp                  2024-01-01T08:00:54.958092
# speed_reading                                   130.8
# Name: 0, dtype: object
# Message 3 published successfully: event_id         f804c4e8-022d-4243-b43e-9ec0860ce6ff
# batch_id                                            2
# car_plate                                     CJW 924
# camera_id                                           3
# timestamp                  2024-01-01T08:00:47.168827
# speed_reading                                   164.5
# Name: 1, dtype: object
# Message 4 published successfully: event_id         a246b391-fb7c-44a3-8f8b-ddf40bba3d05
# batch_id                                            3
# car_plate                                     WA 0712
# camera_id                                           3
# timestamp                  2024-01-01T08:00:53.815270
# speed_reading                                   134.4
# Name: 2, dtype: object
# Message 4 published successfully: event_id         e0dae388-6036-4b7d-ba58-bed0808c1611
# batch_id                                            3
# car_plate                                       KZE 5
# camera_id                                           3
# timestamp                  2024-01-01T08:00:57.613888
# speed_reading                                   125.3
# Name: 3, dtype: object
# Message 5 published successfully: event_id         55a60e1c-818e-4e55-bc02-0627765629b2
# batch_id                                            4
# car_plate                                       ICE 8
# camera_id                                           3
# timestamp                  2024-01-01T08:01:16.405088
# speed_reading                                   108.0
# Name: 4, dtype: object
# Message 5 published successfully: event_id         daafd000-91fa-4ff7-a9bf-896ee74b35ad
# batch_id                                            4
# car_plate                                       WC 89
# camera_id                                           3
# timestamp                  2024-01-01T08:01:18.835653
# speed_reading                                    94.5
# Name: 5, dtype: object
# Message 6 published successfully: event_id         8d6827a6-5ca3-49ac-8d67-f01b64a31c4f
# batch_id                                            5
# car_plate                                       KRN 7
# camera_id                                           3
# timestamp                  2024-01-01T08:01:42.077427
# speed_reading                                    76.2
# Name: 6, dtype: object
# Message 7 published successfully: event_id         052e725b-3098-4f7d-9670-ebcdf30f022c
# batch_id                                            6
# car_plate                                     QE 1820
# camera_id                                           3
# timestamp                  2024-01-01T08:01:50.367291
# speed_reading                                    65.6
# Name: 7, dtype: object
# Message 8 published successfully: event_id         cc084bd6-f680-43cf-9d6e-15bc481038b2
# batch_id                                            7
# car_plate                                    PKH 8115
# camera_id                                           3
# timestamp                  2024-01-01T08:08:52.583094
# speed_reading                                   153.8
# Name: 8, dtype: object
# Message 8 published successfully: event_id         676fa9f2-4a5b-4d1b-a63e-a59b1f2e5c26
# batch_id                                            7
# car_plate                                        PI 9
# camera_id                                           3
# timestamp                  2024-01-01T08:08:53.620450
# speed_reading                                   134.3
# Name: 9, dtype: object
# Message 9 published successfully: event_id         3f49174b-d0fe-4dd6-8cca-cab50d37a21f
# batch_id                                            8
# car_plate                                     EZ 6277
# camera_id                                           3
# timestamp                  2024-01-01T08:09:18.931021
# speed_reading                                    89.8
# Name: 10, dtype: object
# Message 10 published successfully: event_id         65cf39ff-73dc-4873-9a4d-aa0626848af9
# batch_id                                            9
# car_plate                                       KV 17
# camera_id                                           3
# timestamp                  2024-01-01T08:09:25.802177
# speed_reading                                    86.0
# Name: 11, dtype: object
# Message 10 published successfully: event_id         94fd563d-0df1-4b35-a89c-db72f3874b30
# batch_id                                            9
# car_plate                                       QJ 53
# camera_id                                           3
# timestamp                  2024-01-01T08:09:29.843998
# speed_reading                                    82.6
# Name: 12, dtype: object
# Message 11 published successfully: event_id         2f38e970-5042-4d91-8ef3-f8e4bed9908f
# batch_id                                           10
# car_plate                                      CZ 592
# camera_id                                           3
# timestamp                  2024-01-01T08:00:47.453301
# speed_reading                                   161.4
# Name: 13, dtype: object
# Message 11 published successfully: event_id         fa9e3b2a-de4e-48be-b97b-1c01e95e437a
# batch_id                                           10
# car_plate                                        AH 8
# camera_id                                           3
# timestamp                  2024-01-01T08:00:49.247531
# speed_reading                                   165.5
# Name: 14, dtype: object
# Message 12 published successfully: event_id         9a22f424-6c61-4e38-ad58-40c4bde9dfea
# batch_id                                           11
# car_plate                                      FZ 766
# camera_id                                           3
# timestamp                  2024-01-01T08:01:00.555089
# speed_reading                                   143.2
# Name: 15, dtype: object
# Message 13 published successfully: event_id         033183dc-45d4-4cab-98cf-a4f05088c76b
# batch_id                                           12
# car_plate                                      ZPG 90
# camera_id                                           3
# timestamp                  2024-01-01T08:01:16.062056
# speed_reading                                   101.4
# Name: 16, dtype: object
# Message 14 published successfully: event_id         49500aa0-39b9-4dc2-8e4d-69c8519b5983
# batch_id                                           13
# car_plate                                       JEJ 6
# camera_id                                           3
# timestamp                  2024-01-01T08:09:06.369311
# speed_reading                                   109.3
# Name: 17, dtype: object
# Message 15 published successfully: event_id         dfc12ef9-a6d4-48ab-8dab-47eae3e90e1c
# batch_id                                           14
# car_plate                                      IFY 23
# camera_id                                           3
# timestamp                  2024-01-01T08:09:12.383098
# speed_reading                                   115.7
# Name: 18, dtype: object
# Message 16 published successfully: event_id         645454f9-4d9e-4cc9-accc-7048fe7c010a
# batch_id                                           15
# car_plate                                       YRV 3
# camera_id                                           3
# timestamp                  2024-01-01T08:09:53.655566
# speed_reading                                    65.3
# Name: 19, dtype: object
# Message 17 published successfully: event_id         97f44470-dbf6-4c9c-94e9-5fb5b4a9bfb0
# batch_id                                           16
# car_plate                                     KWO 421
# camera_id                                           3
# timestamp                  2024-01-01T08:14:17.095156
# speed_reading                                   118.9
# Name: 20, dtype: object
# Message 18 published successfully: event_id         a012900c-1624-41f9-ae9d-c4ce3f07f061
# batch_id                                           17
# car_plate                                     ZV 2619
# camera_id                                           3
# timestamp                  2024-01-01T08:14:27.485637
# speed_reading                                    93.6
# Name: 21, dtype: object
# Message 19 published successfully: event_id         0a5c01b4-7019-4ab3-86fb-1b10bef30e8f
# batch_id                                           18
# car_plate                                      EOT 00
# camera_id                                           3
# timestamp                  2024-01-01T08:00:54.302613
# speed_reading                                   137.8
# Name: 22, dtype: object
# Message 19 published successfully: event_id         9cd09f0f-7c06-46db-b91e-683b7b9e7547
# batch_id                                           18
# car_plate                                        HP 1
# camera_id                                           3
# timestamp                  2024-01-01T08:00:54.634856
# speed_reading                                   144.3
# Name: 23, dtype: object
# Message 20 published successfully: event_id         9f0d72a2-a98b-4053-b65c-d88baf2571ff
# batch_id                                           19
# car_plate                                     CJP 278
# camera_id                                           3
# timestamp                  2024-01-01T08:01:02.795526
# speed_reading                                   118.6
# Name: 24, dtype: object
# Message 21 published successfully: event_id         283f4049-e9e6-46aa-8f25-94107f08f888
# batch_id                                           20
# car_plate                                     CX 6145
# camera_id                                           3
# timestamp                  2024-01-01T08:01:11.368657
# speed_reading                                   105.0
# Name: 25, dtype: object
# Message 22 published successfully: event_id         332a8fb7-77d6-44c2-a52b-b37b2f3777d2
# batch_id                                           21
# car_plate                                       WJX 2
# camera_id                                           3
# timestamp                  2024-01-01T08:01:17.876767
# speed_reading                                    99.2
# Name: 26, dtype: object
# Message 23 published successfully: event_id         250a7caf-f858-4a3b-8553-ce3ff0dd2c2b
# batch_id                                           22
# car_plate                                       FA 35
# camera_id                                           3
# timestamp                  2024-01-01T08:01:29.666333
# speed_reading                                    86.3
# Name: 27, dtype: object
# Message 24 published successfully: event_id         4154c60d-205c-4b9a-b6f5-3fce0de4602f
# batch_id                                           23
# car_plate                                      WB 418
# camera_id                                           3
# timestamp                  2024-01-01T08:08:49.468866
# speed_reading                                   135.5
# Name: 28, dtype: object
# Message 24 published successfully: event_id         81b00cc5-6329-4799-a1ef-90084142d5c7
# batch_id                                           23
# car_plate                                     UQV 232
# camera_id                                           3
# timestamp                  2024-01-01T08:08:49.576904
# speed_reading                                   169.8
# Name: 29, dtype: object
# Message 25 published successfully: event_id         6929adcc-9074-432d-b802-2bff7bc183eb
# batch_id                                           24
# car_plate                                     DWT 789
# camera_id                                           3
# timestamp                  2024-01-01T08:09:00.148574
# speed_reading                                   130.4
# Name: 30, dtype: object
# Message 25 published successfully: event_id         a47f07b1-cf3e-45a5-8ce9-fe6457c4d960
# batch_id                                           24
# car_plate                                      VWM 13
# camera_id                                           3
# timestamp                  2024-01-01T08:09:01.054869
# speed_reading                                   110.9
# Name: 31, dtype: object
# Message 26 published successfully: event_id         91189d3c-380e-4797-8fde-46c4431d7265
# batch_id                                           25
# car_plate                                      XYG 05
# camera_id                                           3
# timestamp                  2024-01-01T08:09:07.354396
# speed_reading                                   103.0
# Name: 32, dtype: object
# Message 26 published successfully: event_id         949e891a-4559-4589-9087-9314df3dc1a0
# batch_id                                           25
# car_plate                                     DSD 320
# camera_id                                           3
# timestamp                  2024-01-01T08:09:08.960588
# speed_reading                                   121.3
# Name: 33, dtype: object
# Message 27 published successfully: event_id         1ecf1920-14b1-4607-bc4f-a09f1c1c7a2f
# batch_id                                           26
# car_plate                                       BS 03
# camera_id                                           3
# timestamp                  2024-01-01T08:09:13.293701
# speed_reading                                    98.3
# Name: 34, dtype: object
# Message 28 published successfully: event_id         7973c256-0f8e-49cc-bf1d-76b4711e1ef7
# batch_id                                           27
# car_plate                                    WPV 1456
# camera_id                                           3
# timestamp                  2024-01-01T08:09:32.626411
# speed_reading                                    73.6
# Name: 35, dtype: object
# Message 29 published successfully: event_id         2d30d12f-21a9-4f9e-ba8a-96e535da6a0c
# batch_id                                           28
# car_plate                                     CIY 810
# camera_id                                           3
# timestamp                  2024-01-01T08:13:59.546855
# speed_reading                                   135.4
# Name: 36, dtype: object
# Message 29 published successfully: event_id         96d81dd6-ed32-403d-a3e4-4c3f4a2194a6
# batch_id                                           28
# car_plate                                       EC 40
# camera_id                                           3
# timestamp                  2024-01-01T08:14:03.495092
# speed_reading                                   154.7
# Name: 37, dtype: object
# Message 30 published successfully: event_id         1e68bb1d-f6e3-40a8-b24b-6c733061409d
# batch_id                                           29
# car_plate                                       QBF 1
# camera_id                                           3
# timestamp                  2024-01-01T08:14:08.709918
# speed_reading                                   128.9
# Name: 38, dtype: object
# Message 30 published successfully: event_id         12b0a280-758f-42e5-b616-550f7bae7fd2
# batch_id                                           29
# car_plate                                      NGP 66
# camera_id                                           3
# timestamp                  2024-01-01T08:14:11.741826
# speed_reading                                   109.8
# Name: 39, dtype: object
# Message 31 published successfully: event_id         f03b097a-462e-4963-996e-8e38994e61ce
# batch_id                                           30
# car_plate                                    VKZ 5377
# camera_id                                           3
# timestamp                  2024-01-01T08:14:43.211632
# speed_reading                                    75.4
# Name: 40, dtype: object
# Message 32 published successfully: event_id         b939fa8b-5abe-478f-b225-d3a541465d0b
# batch_id                                           31
# car_plate                                    YXA 7534
# camera_id                                           3
# timestamp                  2024-01-01T08:20:33.121746
# speed_reading                                   164.9
# Name: 41, dtype: object
# Message 32 published successfully: event_id         53002012-0061-401e-83a3-553a78035867
# batch_id                                           31
# car_plate                                      XY 025
# camera_id                                           3
# timestamp                  2024-01-01T08:20:35.773241
# speed_reading                                   138.1
# Name: 42, dtype: object
# Message 33 published successfully: event_id         43c9bb24-b749-46f4-9f5e-b6d5191e038a
# batch_id                                           32
# car_plate                                      QK 270
# camera_id                                           3
# timestamp                  2024-01-01T08:20:54.851073
# speed_reading                                   101.2
# Name: 43, dtype: object
# Message 34 published successfully: event_id         ce1a7295-709c-4788-99f2-0f89cc4ba580
# batch_id                                           33
# car_plate                                       KC 82
# camera_id                                           3
# timestamp                  2024-01-01T08:21:05.725636
# speed_reading                                    90.1
# Name: 44, dtype: object
# Message 35 published successfully: event_id         3390b101-e2e8-41d1-b262-e406911086e1
# batch_id                                           34
# car_plate                                      KKE 15
# camera_id                                           3
# timestamp                  2024-01-01T08:00:50.542651
# speed_reading                                   141.3
# Name: 45, dtype: object
# Message 36 published successfully: event_id         f0be3539-15eb-45e4-85cc-320d4db50d8d
# batch_id                                           35
# car_plate                                       FO 32
# camera_id                                           3
# timestamp                  2024-01-01T08:01:15.640881
# speed_reading                                    95.8
# Name: 46, dtype: object
# Message 37 published successfully: event_id         64f98c41-88b7-49d1-b956-b7772c30b8fa
# batch_id                                           36
# car_plate                                       WZ 24
# camera_id                                           3
# timestamp                  2024-01-01T08:08:48.526751
# speed_reading                                   150.7
# Name: 47, dtype: object
# Message 38 published successfully: event_id         01a4864b-46ad-4eb2-a911-43727c6c9c36
# batch_id                                           37
# car_plate                                     VM 4837
# camera_id                                           3
# timestamp                  2024-01-01T08:09:11.510265
# speed_reading                                    97.0
# Name: 48, dtype: object
# Message 39 published successfully: event_id         fe6c7545-0844-492d-a0ae-6e1ba9ba45fe
# batch_id                                           38
# car_plate                                       QZ 81
# camera_id                                           3
# timestamp                  2024-01-01T08:09:58.988288
# speed_reading                                    63.3
# Name: 49, dtype: object
# Message 39 published successfully: event_id         a4ef0b9a-0a3a-4ed5-86c7-83c83f7848b3
# batch_id                                           38
# car_plate                                    AJB 6689
# camera_id                                           3
# timestamp                  2024-01-01T08:09:59.513428
# speed_reading                                    62.5
# Name: 50, dtype: object
# Message 40 published successfully: event_id         0d3b2edd-a679-4aba-8812-ff8645204071
# batch_id                                           39
# car_plate                                       RK 76
# camera_id                                           3
# timestamp                  2024-01-01T08:14:00.882270
# speed_reading                                   132.7
# Name: 51, dtype: object
# Message 40 published successfully: event_id         b67f032a-4a8f-4886-aa70-8f0a85bad105
# batch_id                                           39
# car_plate                                      XCC 09
# camera_id                                           3
# timestamp                  2024-01-01T08:14:03.976783
# speed_reading                                   144.8
# Name: 52, dtype: object
# Message 41 published successfully: event_id         ca4fcb17-29db-4e74-a1c7-0b4293c925eb
# batch_id                                           40
# car_plate                                        GL 4
# camera_id                                           3
# timestamp                  2024-01-01T08:14:08.564138
# speed_reading                                   114.5
# Name: 53, dtype: object
# Message 41 published successfully: event_id         b53daf92-a04b-470b-b7f6-a664986fec12
# batch_id                                           40
# car_plate                                       ZQ 22
# camera_id                                           3
# timestamp                  2024-01-01T08:14:09.023200
# speed_reading                                   111.4
# Name: 54, dtype: object
# Message 42 published successfully: event_id         1a77d4c1-63fa-4ca9-b599-af0f9f6e106e
# batch_id                                           41
# car_plate                                        VZ 8
# camera_id                                           3
# timestamp                  2024-01-01T08:14:23.762903
# speed_reading                                    95.7
# Name: 55, dtype: object
# Message 43 published successfully: event_id         f81d9f5b-5ba9-407c-9809-612de212c06a
# batch_id                                           42
# car_plate                                    ZEA 3530
# camera_id                                           3
# timestamp                  2024-01-01T08:20:35.365308
# speed_reading                                   143.5
# Name: 56, dtype: object
# Message 44 published successfully: event_id         91a3bab8-fa70-4613-852c-634bce2984b6
# batch_id                                           43
# car_plate                                       DOR 6
# camera_id                                           3
# timestamp                  2024-01-01T08:20:48.867512
# speed_reading                                   110.1
# Name: 57, dtype: object
# Message 45 published successfully: event_id         78858d73-7233-4d39-8c20-2891278930a9
# batch_id                                           44
# car_plate                                        BU 9
# camera_id                                           3
# timestamp                  2024-01-01T08:21:01.968054
# speed_reading                                    92.8
# Name: 58, dtype: object
# Message 46 published successfully: event_id         b4cba9e5-4be3-4a81-a70f-f78372052199
# batch_id                                           45
# car_plate                                      VLY 61
# camera_id                                           3
# timestamp                  2024-01-01T08:21:08.699219
# speed_reading                                    80.9
# Name: 59, dtype: object
# Message 46 published successfully: event_id         f7791bb7-92e6-4842-9c83-0512cda7f529
# batch_id                                           45
# car_plate                                    HLZ 1649
# camera_id                                           3
# timestamp                  2024-01-01T08:21:10.109678
# speed_reading                                    89.3
# Name: 60, dtype: object
# Message 47 published successfully: event_id         b1a191f8-65e5-4284-8eaf-e1358240c9c8
# batch_id                                           46
# car_plate                                       WX 49
# camera_id                                           3
# timestamp                  2024-01-01T08:21:14.975844
# speed_reading                                    74.4
# Name: 61, dtype: object
# Message 48 published successfully: event_id         320bc122-d866-487e-9267-2f804ff939fa
# batch_id                                           47
# car_plate                                      BQN 88
# camera_id                                           3
# timestamp                  2024-01-01T08:21:43.579488
# speed_reading                                    61.7
# Name: 62, dtype: object
# Message 49 published successfully: event_id         0f30aa31-610b-4df0-9215-4789735d0bfa
# batch_id                                           48
# car_plate                                      DGT 19
# camera_id                                           3
# timestamp                  2024-01-01T08:26:19.150336
# speed_reading                                   130.6
# Name: 63, dtype: object
# Message 50 published successfully: event_id         9a5d0e8b-24af-44a9-bc31-d01c354fada8
# batch_id                                           49
# car_plate                                      MZ 242
# camera_id                                           3
# timestamp                  2024-01-01T08:13:56.886282
# speed_reading                                   160.8
# Name: 64, dtype: object
# Message 51 published successfully: event_id         a3d27ed2-acff-4e77-b209-d939d423d0d2
# batch_id                                           50
# car_plate                                       VJX 7
# camera_id                                           3
# timestamp                  2024-01-01T08:14:14.721078
# speed_reading                                   119.7
# Name: 65, dtype: object
# Message 51 published successfully: event_id         bcbc2400-fea4-4f4e-aa9f-285ebee4ca2b
# batch_id                                           50
# car_plate                                     WVV 824
# camera_id                                           3
# timestamp                  2024-01-01T08:14:16.669783
# speed_reading                                   110.2
# Name: 66, dtype: object
# Message 52 published successfully: event_id         937d55b5-e7e9-4d6f-989d-6502f2bf2b37
# batch_id                                           51
# car_plate                                        DJ 9
# camera_id                                           3
# timestamp                  2024-01-01T08:14:32.755618
# speed_reading                                    89.9
# Name: 67, dtype: object
# Message 53 published successfully: event_id         b01a3186-9681-4421-bd87-904464098c1d
# batch_id                                           52
# car_plate                                      GI 029
# camera_id                                           3
# timestamp                  2024-01-01T08:15:09.338907
# speed_reading                                    64.4
# Name: 68, dtype: object
# Message 54 published successfully: event_id         9da0f30a-11f3-4842-b592-0091d4bdb015
# batch_id                                           53
# car_plate                                    CDC 5769
# camera_id                                           3
# timestamp                  2024-01-01T08:20:34.333003
# speed_reading                                   150.4
# Name: 69, dtype: object
# Message 55 published successfully: event_id         a6217585-a405-42d4-8360-eb460a9f2965
# batch_id                                           54
# car_plate                                      XYE 28
# camera_id                                           3
# timestamp                  2024-01-01T08:21:23.023195
# speed_reading                                    69.9
# Name: 70, dtype: object
# Message 56 published successfully: event_id         e8570ab2-9230-41de-ac4e-dfe458a092e2
# batch_id                                           55
# car_plate                                       WOQ 4
# camera_id                                           3
# timestamp                  2024-01-01T08:21:30.700352
# speed_reading                                    66.6
# Name: 71, dtype: object
# Message 57 published successfully: event_id         60ac0119-8850-4f4a-afe1-0f39c4838e63
# batch_id                                           56
# car_plate                                        FQ 3
# camera_id                                           3
# timestamp                  2024-01-01T08:26:10.164546
# speed_reading                                   161.2
# Name: 72, dtype: object
# Message 57 published successfully: event_id         d20390fc-13ee-40c7-bf2f-259a069fdec0
# batch_id                                           56
# car_plate                                      JYA 82
# camera_id                                           3
# timestamp                  2024-01-01T08:26:12.117064
# speed_reading                                   133.6
# Name: 73, dtype: object
# Message 57 published successfully: event_id         28036b0a-ff82-402e-9a4c-24e9e1aef377
# batch_id                                           56
# car_plate                                       AFS 0
# camera_id                                           3
# timestamp                  2024-01-01T08:26:12.806842
# speed_reading                                   133.1
# Name: 74, dtype: object
# Message 58 published successfully: event_id         a7189a79-e587-4581-89cc-49b86e9d3323
# batch_id                                           57
# car_plate                                       VC 45
# camera_id                                           3
# timestamp                  2024-01-01T08:26:48.172857
# speed_reading                                    79.4
# Name: 75, dtype: object
# Message 59 published successfully: event_id         6d4a9e15-f7c1-468c-b4bf-c68706564508
# batch_id                                           58
# car_plate                                      KOB 22
# camera_id                                           3
# timestamp                  2024-01-01T08:27:02.016169
# speed_reading                                    73.7
# Name: 76, dtype: object
# Message 60 published successfully: event_id         3681f1d0-76ba-4cfa-826b-6b8bd8795b0f
# batch_id                                           59
# car_plate                                    SAL 1597
# camera_id                                           3
# timestamp                  2024-01-01T08:36:15.462498
# speed_reading                                   140.6
# Name: 77, dtype: object
# Message 61 published successfully: event_id         d210762b-9d89-416b-99d6-e731aadbe91b
# batch_id                                           60
# car_plate                                       KSH 1
# camera_id                                           3
# timestamp                  2024-01-01T08:36:33.967150
# speed_reading                                    96.9
# Name: 78, dtype: object
# Message 62 published successfully: event_id         59f8916d-f925-44fb-ad26-907e580ab804
# batch_id                                           61
# car_plate                                     SS 1621
# camera_id                                           3
# timestamp                  2024-01-01T08:13:59.866147
# speed_reading                                   132.4
# Name: 79, dtype: object
# Message 63 published successfully: event_id         0fde7d8a-4501-40ff-8c51-4257bbb94e81
# batch_id                                           62
# car_plate                                    ARX 7573
# camera_id                                           3
# timestamp                  2024-01-01T08:14:08.836936
# speed_reading                                   113.9
# Name: 80, dtype: object
# Message 64 published successfully: event_id         6d2f1ae3-30b5-41cc-9a01-d41a32510f04
# batch_id                                           63
# car_plate                                        ZZ 8
# camera_id                                           3
# timestamp                  2024-01-01T08:15:05.585777
# speed_reading                                    61.5
# Name: 81, dtype: object
# Message 65 published successfully: event_id         19b11b99-dd36-44c9-90bc-f5e362794739
# batch_id                                           64
# car_plate                                    TZQ 7586
# camera_id                                           3
# timestamp                  2024-01-01T08:20:38.975244
# speed_reading                                   138.1
# Name: 82, dtype: object
# Message 65 published successfully: event_id         a2abfcca-70ef-4f1b-ac75-3f81c5d11cbf
# batch_id                                           64
# car_plate                                       SJ 15
# camera_id                                           3
# timestamp                  2024-01-01T08:20:39.104756
# speed_reading                                   140.5
# Name: 83, dtype: object
# Message 66 published successfully: event_id         4ea72cb9-3a69-4854-a2d9-d172d306036c
# batch_id                                           65
# car_plate                                     CI 9861
# camera_id                                           3
# timestamp                  2024-01-01T08:20:44.871113
# speed_reading                                   118.7
# Name: 84, dtype: object
# Message 67 published successfully: event_id         c67cb41c-8833-4659-89f5-04b6371a6e27
# batch_id                                           66
# car_plate                                       ZCL 3
# camera_id                                           3
# timestamp                  2024-01-01T08:20:58.947057
# speed_reading                                    97.7
# Name: 85, dtype: object
# Message 68 published successfully: event_id         a401558c-8b47-4ae4-be2e-cee442b8c1a8
# batch_id                                           67
# car_plate                                      YY 765
# camera_id                                           3
# timestamp                  2024-01-01T08:21:24.142692
# speed_reading                                    74.2
# Name: 86, dtype: object
# Message 69 published successfully: event_id         c4f51ed4-c925-4889-9a2f-8c3e34d93aa2
# batch_id                                           68
# car_plate                                      ZLY 15
# camera_id                                           3
# timestamp                  2024-01-01T08:26:10.741019
# speed_reading                                   153.5
# Name: 87, dtype: object
# Message 70 published successfully: event_id         9b85a771-6ae5-4b31-9c86-78131ec2ae88
# batch_id                                           69
# car_plate                                     YE 6517
# camera_id                                           3
# timestamp                  2024-01-01T08:26:20.939769
# speed_reading                                   119.7
# Name: 88, dtype: object
# Message 71 published successfully: event_id         162d4fe5-9519-4fd9-857a-0204ba11532a
# batch_id                                           70
# car_plate                                    TAD 5898
# camera_id                                           3
# timestamp                  2024-01-01T08:26:29.495112
# speed_reading                                   112.7
# Name: 89, dtype: object
# Message 72 published successfully: event_id         835c8eb6-6f3c-4675-8b7d-3fba15c58d78
# batch_id                                           71
# car_plate                                        PW 7
# camera_id                                           3
# timestamp                  2024-01-01T08:26:49.807145
# speed_reading                                    90.2
# Name: 90, dtype: object
# Message 73 published successfully: event_id         73569120-03b1-41d8-9478-8eb147bc986c
# batch_id                                           72
# car_plate                                     DAW 165
# camera_id                                           3
# timestamp                  2024-01-01T08:26:55.452108
# speed_reading                                    77.0
# Name: 91, dtype: object
# Message 74 published successfully: event_id         d1173857-9c2a-43f9-a037-65fdc0c21788
# batch_id                                           73
# car_plate                                     TB 5190
# camera_id                                           3
# timestamp                  2024-01-01T08:36:08.660079
# speed_reading                                   150.7
# Name: 92, dtype: object
# Message 74 published successfully: event_id         d5ebe15b-552f-4a4e-81c5-93f957ff6a54
# batch_id                                           73
# car_plate                                    KNT 8153
# camera_id                                           3
# timestamp                  2024-01-01T08:36:10.877278
# speed_reading                                   137.8
# Name: 93, dtype: object
# Message 75 published successfully: event_id         e1438907-28e7-485d-af2b-76b5b4f38423
# batch_id                                           74
# car_plate                                      ZVK 10
# camera_id                                           3
# timestamp                  2024-01-01T08:36:17.444047
# speed_reading                                   132.7
# Name: 94, dtype: object
# Message 75 published successfully: event_id         3e258aa7-dfb3-4e3c-a77e-5a7909e6d389
# batch_id                                           74
# car_plate                                     IF 7805
# camera_id                                           3
# timestamp                  2024-01-01T08:36:18.903653
# speed_reading                                   131.6
# Name: 95, dtype: object
# Message 76 published successfully: event_id         92ceedc7-3976-49cb-bd35-7ba605c77b04
# batch_id                                           75
# car_plate                                       WX 31
# camera_id                                           3
# timestamp                  2024-01-01T08:36:23.356819
# speed_reading                                   119.6
# Name: 96, dtype: object
# Message 77 published successfully: event_id         0f04d3f0-887d-4cee-a295-f473095f2be2
# batch_id                                           76
# car_plate                                      FFG 22
# camera_id                                           3
# timestamp                  2024-01-01T08:36:39.434087
# speed_reading                                    92.8
# Name: 97, dtype: object
# Message 78 published successfully: event_id         de3ebe2f-70ef-4b9e-9721-bea237283069
# batch_id                                           77
# car_plate                                     XWC 903
# camera_id                                           3
# timestamp                  2024-01-01T08:43:32.867932
# speed_reading                                   123.0
# Name: 98, dtype: object
# Message 79 published successfully: event_id         455273e3-489e-46b1-9be6-73bcfa2e8bcf
# batch_id                                           78
# car_plate                                    YTE 8888
# camera_id                                           3
# timestamp                  2024-01-01T08:43:58.345666
# speed_reading                                    91.8
# Name: 99, dtype: object
# Message 80 published successfully: event_id         8d54c0fd-5554-4b90-97d1-b5c2952a323b
# batch_id                                           79
# car_plate                                      CU 131
# camera_id                                           3
# timestamp                  2024-01-01T08:44:05.714894
# speed_reading                                    80.3
# Name: 100, dtype: object
# Message 81 published successfully: event_id         de2b3e1d-d253-4d8b-a7e6-029e46394851
# batch_id                                           80
# car_plate                                     BUB 647
# camera_id                                           3
# timestamp                  2024-01-01T08:44:40.862263
# speed_reading                                    61.7
# Name: 101, dtype: object
# Message 81 published successfully: event_id         d2edbfb2-e181-4657-a58a-b05c60758703
# batch_id                                           80
# car_plate                                     DBF 451
# camera_id                                           3
# timestamp                  2024-01-01T08:44:42.096650
# speed_reading                                    61.5
# Name: 102, dtype: object
# Message 82 published successfully: event_id         27b6759f-2c2a-4103-a668-037aba98695f
# batch_id                                           81
# car_plate                                       PB 55
# camera_id                                           3
# timestamp                  2024-01-01T08:20:54.685198
# speed_reading                                   101.9
# Name: 103, dtype: object
# Message 83 published successfully: event_id         d73c82f8-8405-4353-85a9-4b2b2b4d31fd
# batch_id                                           82
# car_plate                                     QQ 6161
# camera_id                                           3
# timestamp                  2024-01-01T08:26:15.929559
# speed_reading                                   117.5
# Name: 104, dtype: object
# Message 83 published successfully: event_id         b9de14df-b361-4379-83f1-d7c1afd80bd7
# batch_id                                           82
# car_plate                                       ZBR 9
# camera_id                                           3
# timestamp                  2024-01-01T08:26:17.373922
# speed_reading                                   130.1
# Name: 105, dtype: object
# Message 83 published successfully: event_id         6b887dcb-176b-415d-abe7-5b4871ef8bea
# batch_id                                           82
# car_plate                                      AW 965
# camera_id                                           3
# timestamp                  2024-01-01T08:26:19.638669
# speed_reading                                   126.7
# Name: 106, dtype: object
# Message 84 published successfully: event_id         263f1397-838e-47cf-a644-68225d5a4d88
# batch_id                                           83
# car_plate                                     HMU 040
# camera_id                                           3
# timestamp                  2024-01-01T08:36:22.076749
# speed_reading                                   124.4
# Name: 107, dtype: object
# Message 84 published successfully: event_id         4b8cca7a-c904-4891-b9f0-66d7c747f5c3
# batch_id                                           83
# car_plate                                     ZCO 026
# camera_id                                           3
# timestamp                  2024-01-01T08:36:25.107988
# speed_reading                                   113.5
# Name: 108, dtype: object
# Message 85 published successfully: event_id         6bec04b8-b838-449d-9e47-2cf6a41fa1e6
# batch_id                                           84
# car_plate                                     XSG 781
# camera_id                                           3
# timestamp                  2024-01-01T08:37:03.846482
# speed_reading                                    68.9
# Name: 109, dtype: object
# Message 86 published successfully: event_id         f5f20484-0d83-48dc-ac7d-97b7b7624b97
# batch_id                                           85
# car_plate                                      ZG 714
# camera_id                                           3
# timestamp                  2024-01-01T08:43:29.603145
# speed_reading                                   129.8
# Name: 110, dtype: object
# Message 87 published successfully: event_id         6f63ddb9-068c-43e6-a4dc-54564ffb469e
# batch_id                                           86
# car_plate                                     YO 3272
# camera_id                                           3
# timestamp                  2024-01-01T08:43:46.765307
# speed_reading                                   102.3
# Name: 111, dtype: object
# Message 88 published successfully: event_id         035e86de-1faf-4009-bb4d-404ef291c8bd
# batch_id                                           87
# car_plate                                    IMC 6788
# camera_id                                           3
# timestamp                  2024-01-01T08:44:01.782430
# speed_reading                                    91.3
# Name: 112, dtype: object
# Message 89 published successfully: event_id         b91ba6fb-7903-419e-8628-71744fd8d276
# batch_id                                           88
# car_plate                                    BPV 0250
# camera_id                                           3
# timestamp                  2024-01-01T08:44:10.723828
# speed_reading                                    76.5
# Name: 113, dtype: object
# Message 90 published successfully: event_id         41e79aa9-bb6b-4d9a-99e2-5562ee7b1870
# batch_id                                           89
# car_plate                                     MC 2760
# camera_id                                           3
# timestamp                  2024-01-01T08:44:20.522451
# speed_reading                                    72.3
# Name: 114, dtype: object
# Message 91 published successfully: event_id         120640ea-e7b2-48df-8074-0eb34fe320b4
# batch_id                                           90
# car_plate                                      BCZ 29
# camera_id                                           3
# timestamp                  2024-01-01T08:52:19.516028
# speed_reading                                   165.1
# Name: 115, dtype: object
# Message 92 published successfully: event_id         5f26c7e0-11ad-4364-81b4-1d803666d21a
# batch_id                                           91
# car_plate                                     NQ 0051
# camera_id                                           3
# timestamp                  2024-01-01T08:52:51.320876
# speed_reading                                    96.4
# Name: 116, dtype: object
# Message 93 published successfully: event_id         75b84241-fb0e-4959-9c7b-1eb5a46ba7bb
# batch_id                                           92
# car_plate                                       GPR 4
# camera_id                                           3
# timestamp                  2024-01-01T08:26:12.775403
# speed_reading                                   147.2
# Name: 117, dtype: object
# Message 93 published successfully: event_id         1622e80e-1f80-453f-831b-ccc268160d03
# batch_id                                           92
# car_plate                                      REP 98
# camera_id                                           3
# timestamp                  2024-01-01T08:26:14.216976
# speed_reading                                   130.8
# Name: 118, dtype: object
# Message 93 published successfully: event_id         129b394f-b4d0-4ee6-8e3f-0bff351f7d96
# batch_id                                           92
# car_plate                                     IMU 122
# camera_id                                           3
# timestamp                  2024-01-01T08:26:14.343592
# speed_reading                                   130.1
# Name: 119, dtype: object
# Message 93 published successfully: event_id         bed94794-683f-4ba3-89d4-39dcbb0f6efe
# batch_id                                           92
# car_plate                                        OW 5
# camera_id                                           3
# timestamp                  2024-01-01T08:26:16.072236
# speed_reading                                   141.9
# Name: 120, dtype: object
# Message 94 published successfully: event_id         acf9f8c6-9322-40df-ae5e-0bff7e11ff9c
# batch_id                                           93
# car_plate                                     WX 2585
# camera_id                                           3
# timestamp                  2024-01-01T08:26:31.105376
# speed_reading                                   107.6
# Name: 121, dtype: object
# Message 95 published successfully: event_id         231a6eb9-4bae-4695-95fb-32ccf96275f9
# batch_id                                           94
# car_plate                                      IU 033
# camera_id                                           3
# timestamp                  2024-01-01T08:26:55.462725
# speed_reading                                    77.6
# Name: 122, dtype: object
# Message 96 published successfully: event_id         0a65a170-2fae-4032-be49-100c24b2dc97
# batch_id                                           95
# car_plate                                       KNZ 1
# camera_id                                           3
# timestamp                  2024-01-01T08:36:14.026159
# speed_reading                                   121.5
# Name: 123, dtype: object
# Message 96 published successfully: event_id         3b75072b-24b5-4c92-9837-e1c2bc8667c6
# batch_id                                           95
# car_plate                                      WK 223
# camera_id                                           3
# timestamp                  2024-01-01T08:36:16.656710
# speed_reading                                   123.0
# Name: 124, dtype: object
# Message 97 published successfully: event_id         5812d28c-08bf-4d56-af08-9b244c72f437
# ...
# speed_reading                                   148.2
# Name: 2999, dtype: object
# Message 2230 published successfully: event_id         3376ece7-6c64-41f6-8a10-14a245918670
# batch_id                                         2229
# car_plate                                    PVD 9063
# camera_id                                           3
# timestamp                  2024-01-02T17:38:22.266197
# speed_reading                                    80.4
# Name: 3000, dtype: object
# Message 2231 published successfully: event_id         8a2c67f2-a671-4319-a791-be079be03ff7
# batch_id                                         2230
# car_plate                                     MT 9009
# camera_id                                           3
# timestamp                  2024-01-02T17:44:19.876616
# speed_reading                                   111.1
# Name: 3001, dtype: object
# Message 2231 published successfully: event_id         a7a69775-15d2-48f5-91ef-9fed162088c5
# batch_id                                         2230
# car_plate                                      WWO 38
# camera_id                                           3
# timestamp                  2024-01-02T17:44:24.259784
# speed_reading                                   101.9
# Name: 3002, dtype: object
# Message 2232 published successfully: event_id         b656f9a4-da94-4cba-985b-db4759ac419f
# batch_id                                         2231
# car_plate                                      XID 18
# camera_id                                           3
# timestamp                  2024-01-02T17:44:35.636435
# speed_reading                                    87.7
# Name: 3003, dtype: object
# Message 2233 published successfully: event_id         4e67ce46-b9cd-4674-a78d-6fd700fbf165
# batch_id                                         2232
# car_plate                                        UF 4
# camera_id                                           3
# timestamp                  2024-01-02T17:44:42.698866
# speed_reading                                    85.5
# Name: 3004, dtype: object
# Message 2234 published successfully: event_id         b3fd12b0-15c1-44fb-a8e4-7a8aaf7eb2a9
# batch_id                                         2233
# car_plate                                      KV 400
# camera_id                                           3
# timestamp                  2024-01-02T17:45:01.770020
# speed_reading                                    65.2
# Name: 3005, dtype: object
# Message 2235 published successfully: event_id         7e703ae4-3204-45d0-8536-38e2717fb812
# batch_id                                         2234
# car_plate                                       JM 10
# camera_id                                           3
# timestamp                  2024-01-02T17:53:37.156282
# speed_reading                                   146.5
# Name: 3006, dtype: object
# Message 2235 published successfully: event_id         4463d4d8-c6f5-40a5-89d0-8539980c6024
# batch_id                                         2234
# car_plate                                      KCE 20
# camera_id                                           3
# timestamp                  2024-01-02T17:53:37.223921
# speed_reading                                   137.3
# Name: 3007, dtype: object
# Message 2235 published successfully: event_id         06b37e13-d792-46de-a155-ec9d74b66601
# batch_id                                         2234
# car_plate                                      FOE 62
# camera_id                                           3
# timestamp                  2024-01-02T17:53:38.551163
# speed_reading                                   138.4
# Name: 3008, dtype: object
# Message 2235 published successfully: event_id         a9b5d4e1-686e-4428-8e2a-a428b9994347
# batch_id                                         2234
# car_plate                                        VT 4
# camera_id                                           3
# timestamp                  2024-01-02T17:53:41.561896
# speed_reading                                   132.6
# Name: 3009, dtype: object
# Message 2236 published successfully: event_id         ed636e65-3f41-41c6-b948-a550aee38aef
# batch_id                                         2235
# car_plate                                     TU 8737
# camera_id                                           3
# timestamp                  2024-01-02T17:53:45.898846
# speed_reading                                   128.8
# Name: 3010, dtype: object
# Message 2237 published successfully: event_id         8dcfbe9b-0bfa-46a9-be72-f518b09ee8d4
# batch_id                                         2236
# car_plate                                     YK 2207
# camera_id                                           3
# timestamp                  2024-01-02T17:54:23.418452
# speed_reading                                    79.0
# Name: 3011, dtype: object
# Message 2238 published successfully: event_id         89ce46bd-b33b-4ff1-a81c-68be5e49f904
# batch_id                                         2237
# car_plate                                     ZLD 652
# camera_id                                           3
# timestamp                  2024-01-02T17:59:14.672205
# speed_reading                                   119.0
# Name: 3012, dtype: object
# Message 2239 published successfully: event_id         22c839a8-878b-4ebd-8c90-e4bca19fdfcf
# batch_id                                         2238
# car_plate                                      SCO 83
# camera_id                                           3
# timestamp                  2024-01-02T17:59:26.601955
# speed_reading                                    99.3
# Name: 3013, dtype: object
# Message 2240 published successfully: event_id         82071b1e-1fd6-41b7-b7ae-c89a26bfd1cb
# batch_id                                         2239
# car_plate                                       RE 21
# camera_id                                           3
# timestamp                  2024-01-02T18:05:27.213048
# speed_reading                                   109.7
# Name: 3014, dtype: object
# Message 2241 published successfully: event_id         4eb3684e-a469-46c4-9fc4-e53844bb22a4
# batch_id                                         2240
# car_plate                                    BUV 4934
# camera_id                                           3
# timestamp                  2024-01-02T17:44:09.441226
# speed_reading                                   145.7
# Name: 3015, dtype: object
# Message 2242 published successfully: event_id         a6bb0626-1d0c-45e0-aeee-6219d07a2fd5
# batch_id                                         2241
# car_plate                                       CH 30
# camera_id                                           3
# timestamp                  2024-01-02T17:44:15.429129
# speed_reading                                   126.8
# Name: 3016, dtype: object
# Message 2243 published successfully: event_id         c42b9ce0-a3e6-483a-a0a4-304f0e8dfc4c
# batch_id                                         2242
# car_plate                                     UM 5589
# camera_id                                           3
# timestamp                  2024-01-02T17:45:01.135348
# speed_reading                                    70.0
# Name: 3017, dtype: object
# Message 2243 published successfully: event_id         315d90d3-0200-4385-9bd1-688e624e81e8
# batch_id                                         2242
# car_plate                                     HTU 273
# camera_id                                           3
# timestamp                  2024-01-02T17:45:02.581222
# speed_reading                                    67.3
# Name: 3018, dtype: object
# Message 2244 published successfully: event_id         0e0a2b74-f488-4b06-a022-5b30eb3bd1a7
# batch_id                                         2243
# car_plate                                     AVK 647
# camera_id                                           3
# timestamp                  2024-01-02T17:53:31.270508
# speed_reading                                   158.8
# Name: 3019, dtype: object
# Message 2244 published successfully: event_id         6f8617f1-7cdf-472c-9150-70629ae297a7
# batch_id                                         2243
# car_plate                                       EG 20
# camera_id                                           3
# timestamp                  2024-01-02T17:53:32.338768
# speed_reading                                   148.7
# Name: 3020, dtype: object
# Message 2245 published successfully: event_id         ee811773-5de9-47a1-b2e2-ad9e935cbe32
# batch_id                                         2244
# car_plate                                      DUC 43
# camera_id                                           3
# timestamp                  2024-01-02T17:53:39.891973
# speed_reading                                   140.7
# Name: 3021, dtype: object
# Message 2246 published successfully: event_id         4c6b1d53-bc1f-462c-be80-20281c6237ea
# batch_id                                         2245
# car_plate                                      ML 782
# camera_id                                           3
# timestamp                  2024-01-02T17:53:59.599821
# speed_reading                                    98.1
# Name: 3022, dtype: object
# Message 2246 published successfully: event_id         96284bac-dc94-4c3b-af52-f86894113754
# batch_id                                         2245
# car_plate                                      ANF 57
# camera_id                                           3
# timestamp                  2024-01-02T17:54:04.054688
# speed_reading                                    98.0
# Name: 3023, dtype: object
# Message 2247 published successfully: event_id         21dd74b9-cfac-4c1b-b4ef-783c4658ace3
# batch_id                                         2246
# car_plate                                       CKI 2
# camera_id                                           3
# timestamp                  2024-01-02T17:54:12.748291
# speed_reading                                    78.3
# Name: 3024, dtype: object
# Message 2248 published successfully: event_id         4d532e35-62f6-46f9-9d39-723b985b40c3
# batch_id                                         2247
# car_plate                                     UKR 404
# camera_id                                           3
# timestamp                  2024-01-02T17:58:54.240132
# speed_reading                                   142.0
# Name: 3025, dtype: object
# Message 2248 published successfully: event_id         53c28c7f-e607-4041-b420-253973deabad
# batch_id                                         2247
# car_plate                                     GKW 542
# camera_id                                           3
# timestamp                  2024-01-02T17:58:57.130623
# speed_reading                                   168.7
# Name: 3026, dtype: object
# Message 2248 published successfully: event_id         730c791c-999a-41f3-8b4b-2972c256e6af
# batch_id                                         2247
# car_plate                                      OG 192
# camera_id                                           3
# timestamp                  2024-01-02T17:58:57.184773
# speed_reading                                   154.4
# Name: 3027, dtype: object
# Message 2248 published successfully: event_id         04fba68d-1c07-461e-a494-1b39425e047c
# batch_id                                         2247
# car_plate                                      DQQ 13
# camera_id                                           3
# timestamp                  2024-01-02T17:58:58.363179
# speed_reading                                   153.2
# Name: 3028, dtype: object
# Message 2249 published successfully: event_id         0a83ec5b-ec34-4504-8537-dd388e5232bf
# batch_id                                         2248
# car_plate                                    WIP 4251
# camera_id                                           3
# timestamp                  2024-01-02T17:59:00.121986
# speed_reading                                   133.0
# Name: 3029, dtype: object
# Message 2249 published successfully: event_id         5a068b59-e31b-471e-80bb-e39e5a9aed3d
# batch_id                                         2248
# car_plate                                       YPO 6
# camera_id                                           3
# timestamp                  2024-01-02T17:59:04.820783
# speed_reading                                   139.5
# Name: 3030, dtype: object
# Message 2250 published successfully: event_id         3a262c19-9c54-46a2-aae8-b9ed2be95451
# batch_id                                         2249
# car_plate                                      CVQ 37
# camera_id                                           3
# timestamp                  2024-01-02T17:59:07.534367
# speed_reading                                   130.5
# Name: 3031, dtype: object
# Message 2251 published successfully: event_id         2b8fe8bf-53c4-4cde-b034-74320fcc2827
# batch_id                                         2250
# car_plate                                    EUW 9274
# camera_id                                           3
# timestamp                  2024-01-02T17:59:37.231474
# speed_reading                                    83.6
# Name: 3032, dtype: object
# Message 2252 published successfully: event_id         8027d994-e57d-44ab-8456-b07cc17a7389
# batch_id                                         2251
# car_plate                                     VX 2701
# camera_id                                           3
# timestamp                  2024-01-02T17:59:55.104352
# speed_reading                                    68.2
# Name: 3033, dtype: object
# Message 2253 published successfully: event_id         4f5f2718-75ea-464d-90d2-832b50d35df9
# batch_id                                         2252
# car_plate                                      TKR 17
# camera_id                                           3
# timestamp                  2024-01-02T18:05:32.093442
# speed_reading                                   108.0
# Name: 3034, dtype: object
# Message 2253 published successfully: event_id         2ff596e8-1563-453a-89f2-10ca5516d3c9
# batch_id                                         2252
# car_plate                                     EIQ 917
# camera_id                                           3
# timestamp                  2024-01-02T18:05:33.235684
# speed_reading                                   101.7
# Name: 3035, dtype: object
# Message 2254 published successfully: event_id         32bc588c-534c-4c85-ba99-c95505145b96
# batch_id                                         2253
# car_plate                                     TLX 990
# camera_id                                           3
# timestamp                  2024-01-02T18:15:13.290367
# speed_reading                                   124.9
# Name: 3036, dtype: object
# Message 2255 published successfully: event_id         99b8a2e3-9397-44b4-9ad4-bcedda203ce2
# batch_id                                         2254
# car_plate                                       KJY 3
# camera_id                                           3
# timestamp                  2024-01-02T17:59:02.913538
# speed_reading                                   149.9
# Name: 3037, dtype: object
# Message 2255 published successfully: event_id         11f5b2b9-9c8c-42a9-b6b7-43964c0c524b
# batch_id                                         2254
# car_plate                                    PRD 1181
# camera_id                                           3
# timestamp                  2024-01-02T17:59:07.389462
# speed_reading                                   120.7
# Name: 3038, dtype: object
# Message 2256 published successfully: event_id         639b8ff1-dac7-499a-b666-b4accbe23a39
# batch_id                                         2255
# car_plate                                      WA 298
# camera_id                                           3
# timestamp                  2024-01-02T17:59:30.312630
# speed_reading                                    90.8
# Name: 3039, dtype: object
# Message 2256 published successfully: event_id         0b1c6bea-d5c6-479b-bd95-d84ab1af86c3
# batch_id                                         2255
# car_plate                                      NTA 92
# camera_id                                           3
# timestamp                  2024-01-02T17:59:33.597106
# speed_reading                                    86.1
# Name: 3040, dtype: object
